# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns
# %matplotlib inline  
from sklearn.model_selection import StratifiedKFold
from joblib import load, dump
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import confusion_matrix
from fastai import *
from fastai.vision import *
from fastai.callbacks import *
from torchvision import models as md
from efficientnet_pytorch import EfficientNet

md_ef =  EfficientNet.from_pretrained('efficientnet-b5', num_classes=1)
# Out:
# Loaded pretrained weights for efficientnet-b5

# %%
EXP_NAME = 'NB_EXP_725'
PATH = Path('../')
OLD_TRAIN = PATH/'old_train.csv'
OLD_TEST  = PATH/'old_test.csv'
TRAIN     = PATH/'train.csv'
IMG_OLD_TRAIN_224 = PATH/'old_train_images_224'
IMG_OLD_TEST_224  = PATH/'old_test_images_224'
IMG_TRAIN_224     = PATH/'train_images_224'
BS = 128
SZ = 224

# %%
def apply_path(path, exten, df, col_name='image'):
    df[col_name] = df[col_name].apply(lambda x: f'{str(path)}/{x}{exten}')
    return df


def get_ign_list(df):
    ignore_list = ["00cb6555d108.png", "012a242ac6ff.png", "0161338f53cc.png", "025a169a0bb0.png","026dcd9af143.png", "034cb07a550f.png", "03676c71ed1b.png", "04ac765f91a1.png", "05a5183c92d0.png", "07419eddd6be.png", "0c7e82daf5a0.png","0dce95217626.png", "1006345f70b7.png", "111898ab463d.png", "11242a67122d.png", "12e3f5f2cb17.png", "135575dc57c9.png", "1411c8ab7161.png","144b01e7b993.png", "14515b8f19b6.png", "1638404f385c.png", "19722bff5a09.png", "1a1b4b2450ca.png", "1ae8c165fd53.png", "1b4625877527.png", "1c5e6cdc7ee1.png", "1c6d119c3d70.png", "1cb814ed6332.png", "1dfbede13143.png", "1e8a1fdee5b9.png", "a47432cd41e7.png", "1e9224ccca95.png", "1ee1eb7943db.png", "22895c89792f.png", "23d7ca170bdb.png", "26e231747848.png", "2923971566fe.png", "2b21d293fdf2.png", "2cceb07ff706.png", "36041171f441.png", "36677b70b1ef.png", "38487e1a5b1f.png", "3a1d3ce00f0c.png", "3b4a5fcbe5e0.png", "3f44d749cd0b.png", "3fd7df6099e3.png", "40e9b5630438.png", "e4e343eaae2a.png", "48c49f662f7d.png", "4ce74e5eb51d.png", "4d7d6928534a.png", "530d78467615.png", "5b76117c4bcb.png", "5dc23e440de3.png", "6b00cb764237.png", "65e51e18242b.png", "68332fdcaa70.png", "6c3745a222da.png", "71c1a3cdbe47.png", "7550966ef777.png", "75a7bc945b7d.png", "7877be80901c.png", "7a0cff4c24b2.png", "7a3ea1779b13.png", "a8582e346df0.png", "c027e5482e8c.png", "7b691d9ced34.png", "7d261f986bef.png", "7e160c8b611e.png", "80d24897669f.png", "80feb1f7ca5e.png", "840527bc6628.png", "8fc09fecd22f.png", "9b32e8ef0ca0.png", "9b418ce42c13.png", "9b7b6e4db1d5.png", "9c5dd3612f0c.png", "9f1efb799b7b.png", "a505981d1cab.png", "a8b637abd96b.png", "aca88f566228.png", "aeed1f251ceb.png", "b06dabab4f09.png", "b13d72ceea26.png", "b8ac328009e0.png", "ba735b286d62.png", "bb7e0a2544cd.png", "bcdc8db5423b.png", "bfefa7344e7d.png", "ca0f1a17c8e5.png", "ca891d37a43c.png", "cd3fd04d72f5.png", "ce887b196c23.png", "d28bd830c171.png", "d51b3fe0fa1b.png", "f1a761c68559.png", "51131b48f9d4.png", "42a850acd2ac.png"]
    ts = []
    for k, i in enumerate(df['image']):
        if i.split('/')[-1] in ignore_list:
            ts.append(k)
            
    bad_list = df.index.isin(ts)
    df_local = df[~bad_list].copy()
    df_local.reset_index(inplace=True, drop=True)
    return df_local


def get_all_data():
    df_old_test = pd.read_csv(OLD_TEST).drop('Usage', axis=1)
    df_old_train = pd.read_csv(OLD_TRAIN)
    df_train = pd.read_csv(TRAIN)
    
    df_old_train.columns = ['image', 'labels']
    df_train.columns = ['image', 'labels']
    df_old_test.columns = ['image', 'labels']
    
    
    apply_path(IMG_OLD_TRAIN_224, '.jpeg', df_old_train)
    apply_path(IMG_OLD_TEST_224, '.jpeg', df_old_test)
    apply_path(IMG_TRAIN_224, '.png', df_train)
    
    return pd.concat([df_old_test, df_old_train, get_ign_list(df_train)], ignore_index=True)


def quadratic_kappa(y_hat, y):
    return torch.tensor(cohen_kappa_score(torch.round(y_hat), y, weights='quadratic'),device='cuda:0')

# %%
df = get_all_data()

tfms = get_transforms(do_flip=True, 
                      flip_vert=True,
                      max_rotate=360,
                      max_zoom=1.3, 
                      max_lighting=0.1,
                      p_lighting=0.5, 
                      xtra_tfms=zoom_crop(scale=(0.9, 1.4), do_rand=True))


data = ( ImageList.from_df(df=df, path='', cols='image')
        .split_by_idx(list(range(df.shape[0]-3662, df.shape[0])))
        .label_from_df(cols='labels', label_cls=FloatList)
        .transform(tfms,size=SZ) #Data augmentation
        .databunch(bs=BS)
        .normalize(imagenet_stats)     
       )

# %%
data.show_batch()

# %%
learn = Learner(data, md_ef, metrics = [quadratic_kappa], model_dir="models")
learn.model = nn.DataParallel(learn.model)
learn.to_fp16()
learn.unfreeze()
learn.lr_find()

# %%
lr = 1e-3
learn.recorder.plot()
plt.axvline(lr)

# %%
SUFFIX = 'FREEZE_P1'
learn.fit_one_cycle(10,
                    lr, 
                    wd=1e-2,
                    div_factor=10, 
                    pct_start=0.3,
                    callbacks=[SaveModelCallback(learn, every='improvement', monitor='valid_loss', name = f'{EXP_NAME}_{SUFFIX}')])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>quadratic_kappa</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.493173</td>
#       <td>0.363207</td>
#       <td>0.876366</td>
#       <td>12:17</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.501593</td>
#       <td>0.361940</td>
#       <td>0.860044</td>
#       <td>12:17</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.487596</td>
#       <td>0.505581</td>
#       <td>0.837413</td>
#       <td>12:15</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.447064</td>
#       <td>0.388448</td>
#       <td>0.870564</td>
#       <td>12:17</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.435967</td>
#       <td>0.619482</td>
#       <td>0.836688</td>
#       <td>12:15</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.410550</td>
#       <td>0.349161</td>
#       <td>0.874103</td>
#       <td>12:18</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.365244</td>
#       <td>0.390770</td>
#       <td>0.883345</td>
#       <td>12:18</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.358705</td>
#       <td>0.442748</td>
#       <td>0.867660</td>
#       <td>12:18</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.345731</td>
#       <td>0.431500</td>
#       <td>0.872389</td>
#       <td>12:16</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.343808</td>
#       <td>0.406298</td>
#       <td>0.876896</td>
#       <td>12:15</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.36320731043815613.
# Better model found at epoch 1 with valid_loss value: 0.36193978786468506.
# Better model found at epoch 5 with valid_loss value: 0.3491610288619995.

# %%
SUFFIX = 'UNFREEZE_P2'
learn.fit_one_cycle(5,
                    lr/5, 
                    wd=1e-2,
                    div_factor=10, 
                    pct_start=0.3,
                    callbacks=[SaveModelCallback(learn, every='improvement', monitor='valid_loss', name = f'{EXP_NAME}_{SUFFIX}')])
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4' class='' max='5', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       80.00% [4/5 49:14<12:18]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>quadratic_kappa</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.354658</td>
#       <td>0.412006</td>
#       <td>0.876343</td>
#       <td>12:16</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.357276</td>
#       <td>0.410701</td>
#       <td>0.874472</td>
#       <td>12:18</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.355965</td>
#       <td>0.436560</td>
#       <td>0.871494</td>
#       <td>12:19</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.345165</td>
#       <td>0.388939</td>
#       <td>0.880416</td>
#       <td>12:18</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='688' class='' max='692', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       99.42% [688/692 12:01<00:04 0.3304]
#     </div>
# Better model found at epoch 0 with valid_loss value: 0.41200634837150574.
# Better model found at epoch 1 with valid_loss value: 0.4107005000114441.
# Better model found at epoch 3 with valid_loss value: 0.38893941044807434.

# %%
learn.load('NB_EXP_725_UNFREEZE_P2')
learn.unfreeze()
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
lr = 1e-3/8
learn.recorder.plot()
plt.axvline(lr)

# %%
SUFFIX = 'UNFREEZE_P3'
learn.unfreeze()
learn.fit_one_cycle(30,
                    lr, 
                    wd=1e-2,
                    div_factor=10, 
                    pct_start=0.3,
                    callbacks=[SaveModelCallback(learn, every='improvement', monitor='valid_loss', name = f'{EXP_NAME}_{SUFFIX}')])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>quadratic_kappa</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.336058</td>
#       <td>0.403462</td>
#       <td>0.879443</td>
#       <td>12:10</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.337340</td>
#       <td>0.398064</td>
#       <td>0.879600</td>
#       <td>12:11</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.337357</td>
#       <td>0.395154</td>
#       <td>0.878946</td>
#       <td>12:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.328626</td>
#       <td>0.401723</td>
#       <td>0.879672</td>
#       <td>12:12</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0